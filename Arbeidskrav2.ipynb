# %% [markdown]
# <h1>Arbidskrav 2 Py1010</h1>
#
#  Oppgave 1

# %%
from datetime import date as dt

idagÅrstall= dt.today().year
fødtÅrstall = int(input("Hvilket år er du født?"))
alder = idagÅrstall-fødtÅrstall

print ("Du er",alder, "gammel")

# %% [markdown]
# Oppgave 2

# %%
antall_elever = int(input("Skriv inn antall elever:"))
antall_pizza = antall_elever*0.25
print ("Du må kjøpe", int(round(antall_pizza,0)),"pizza")

# %% [markdown]
# Oppgave 3

# %%
import numpy as np
v_grad = float(input("Skriv inn gradtallet:" ))

def v_radiantallet(x):
    y = x*np.pi/180 
    return y

v_rad =v_radiantallet(v_grad)


print('Gradtallet',v_grad,'som du har valgt til følgende radian ', v_rad)

# %% [markdown]
# Oppgave 4

# %%
try: #sjekker om landet finnes i dictionary
    hvilketLand = input('Hvilket land vil du vite mer om: ')
    data = {
        "Norge": ["Oslo", 0.634],
        "England": ["London", 8.982],
        "Frankrike": ["Paris", 2.161],
        "Italia": ["Roma", 2.873]
    }

    print(data[hvilketLand])

except Error: # hvis land ikke finnes får bruker beskjed, og spørsmål om han vil legge til 
    print('Landet du har spurt etter finnes ikke i dictionary')

    if bool(input('Vil du oppdatere dictionary med nytt land? (True/False): ')) == True:
        leggTilLand = input('Hvilket land vil du legge til: ')
        leggTilHovedstad = input('Hva er hovedstaden: ')
        leggTilFolketall = int(input('Hvor mange innbyggere: '))
        
        data[leggTilLand] = [leggTilHovedstad, leggTilFolketall]
        print(data)
    else:
        print(data)

# %% [markdown]
# Oppgave 5

# %%
import numpy as np

def fun_areal(a,b):
    
    # finn areal av figur
    arealTrekant = (a*b)/2
    r = a/2
    arealHalvsirkel = (np.pi*r**2)/2
    totAreal = arealTrekant + arealHalvsirkel
    
    # finn omkrets av figur
    finnHypotenus = np.sqrt(a**2+b**2)
    omkretsTrekant =finnHypotenus + a + b
    omkretsHalvsirkel = (2*np.pi*r)/2
    totOmkrets =omkretsTrekant + omkretsHalvsirkel
    
    return(totAreal,totOmkrets)


lengde = int(input('Oppgi lengden på trekant'))
høyde = int(input('Oppgi høyde på trekant')) 

(arealFigur,omkretsFigur) = fun_areal(høyde,lengde)


print('Arealet for figuren er:',arealFigur)
print('Omkretsen for figuren er:',omkretsFigur)

# %% [markdown]
# Oppgave 6

# %%
import numpy as np
import matplotlib.pyplot as plt

varX = int(input('Hvilket tall skal utgjøre x :'))

def fun_plot(varX):

    x = np.linspace(-varX,varX,num=200)

    y = -(x*x)-5 

    return (x,y)


(x_value,y_value) =fun_plot(varX)


plt.plot(x_value,y_value,color='darkGreen',linestyle=':')
plt.xlabel("x verdier")
plt.ylabel("y verdier")
plt.grid()
